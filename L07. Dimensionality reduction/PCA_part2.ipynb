# %%
# !pip install seaborn
# !pip install sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/ivan/.local/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/ivan/.local/lib/python3.8/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: scipy>=1.0 in /home/ivan/.local/lib/python3.8/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in /home/ivan/.local/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in /home/ivan/.local/lib/python3.8/site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ivan/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.2->seaborn) (7.0.0)
# Requirement already satisfied: pytz>=2017.3 in /home/ivan/.local/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/ivan/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: setuptools in /home/ivan/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (59.4.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/ivan/.local/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/ivan/.local/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/ivan/.local/lib/python3.8/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /home/ivan/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/ivan/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /home/ivan/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ivan/.local/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.0.0)

# %% [raw]
# How to work with files:
# 1. use getDataset script, it'll download the file where needed. You can continue working with the downloaded file as usual
# 2. use url in pd.read_csv(url). I'd suggest avoiding this method, as:
#     a. it downloads file every run
#     b. url might break
#     c. need of internet access

# %%
filename = 'london_merged.csv'

# %%
#source: #https://www.kaggle.com/hmavrodiev/london-bike-sharing-dataset

def bar_custom(current, total, width=100):
    print("Downloading: %d%% [%d / %d] bytes" % (current / total * 100, current, total))

#Don't think too much about the getDataset method. It is used for convenience
def getDataset(filename, **kwargs):
    url = f'https://github.com/IvanReznikov/mdx-msc-data-science/raw/main/datasets/{filename}'
    try:
        import os
        if filename not in os.listdir():
            # !pip3 install wget
            import wget
            downloaded_filename = wget.download(url)
            print(f'{downloaded_filename} file downloaded', bar=bar_custom)
        else:
            print(f'{filename} already exists')
        return pd.read_csv(filename, **kwargs)
        
    except Exception as e:
        print(e)
        return pd.read_csv(url, **kwargs)

# %%
trip_df = getDataset(filename)
trip_df.head(3)
# Out:
# london_merged.csv already exists
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5  96.5         0.0           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0

# %% [raw]
# "timestamp" - timestamp field for grouping the data
# "cnt" - the count of a new bike shares
# "t1" - real temperature in C
# "t2" - temperature in C "feels like"
# "hum" - humidity in percentage
# "windspeed" - wind speed in km/h
# "weathercode" - category of the weather
# "isholiday" - boolean field - 1 holiday / 0 non holiday
# "isweekend" - boolean field - 1 if the day is weekend
# "season" - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity 2 = scattered clouds / few clouds 3 = Broken clouds 4 = Cloudy 7 = Rain/ light Rain shower/ Light rain 10 = rain with thunderstorm 26 = snowfall 94 = Freezing Fog

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ivan/.local/lib/python3.8/site-packages (22.0.3)

# %%
trip_df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
#simple fe
trip_df['timestamp'] = pd.to_datetime(trip_df['timestamp'])
trip_df['hour'] = trip_df['timestamp'].dt.hour
trip_df['is_daytime'] = trip_df['hour'].apply(lambda x: True if (x >= 7 and x < 19) else False)
trip_df['is_weekend'] = trip_df['is_weekend'].astype(bool)
trip_df['is_holiday'] = trip_df['is_holiday'].astype(bool)

# %%
#For the moment we'll drop the number of bike shares. We will use it later in the course as target column

trip_df.drop(['cnt', 'timestamp'], axis=1, inplace=True)

# %%
trip_df.shape, trip_df.dtypes
# Out:
# ((17414, 10),
#  t1              float64
#  t2              float64
#  hum             float64
#  wind_speed      float64
#  weather_code    float64
#  is_holiday         bool
#  is_weekend         bool
#  season          float64
#  hour              int64
#  is_daytime         bool
#  dtype: object)

# %%
sns.heatmap(trip_df.corr())
plt.show()

# %% [markdown]
# ## PoC for small dataset

# %%
mini_trip_df = trip_df[trip_df['season']==0].sample(n=50, random_state=42)

# %%
mini_trip_df
# Out:
#          t1    t2   hum  wind_speed  weather_code  is_holiday  is_weekend  \
# 11125  14.5  14.5  55.0         5.5           1.0       False       False
# 10531   6.0   3.0  73.5        17.0           4.0       False        True
# 2874   13.5  13.5  77.0        21.0           7.0        True       False
# 1756    5.0   2.0  87.0        11.0           2.0       False       False
# 12029  14.0  14.0  79.5        12.0           3.0       False        True
# 10403   8.5   4.5  48.0        34.0           1.0       False       False
# 10657   9.0   6.5  79.0        15.0           7.0        True       False
# 11901  17.0  17.0  42.0        19.5           1.0       False       False
# 1903    7.0   5.0  71.0        10.0           2.0       False       False
# 2734    5.5   1.5  78.5        20.5           1.0       False       False
# 1803    5.0   2.0  87.0        12.0           4.0       False       False
# 2506   12.0  12.0  44.0        30.5           1.0       False        True
# 11665  14.0  14.0  72.0        11.0           1.0       False       False
# 11199   9.0   7.0  48.0        12.0           3.0       False        True
# 10867  16.0  16.0  53.5        13.0           1.0       False        True
# 11888  10.0   9.0  88.0         9.0           1.0       False       False
# 11855  11.5  11.5  54.5        11.0           1.0       False        True
# 11666  14.0  14.0  74.5        11.0           1.0       False       False
# 11273  13.0  13.0  59.0        26.0           1.0       False       False
# 1886   11.0  11.0  50.0        10.0           3.0       False       False
# 2655   13.0  13.0  79.5        17.0           4.0       False       False
# 12149  11.0  11.0  88.0        13.0           1.0       False       False
# 11155  11.5  11.5  82.5        15.0           7.0       False       False
# 10163   7.5   5.0  47.5        15.0           7.0       False       False
# 12252  11.0  11.0  94.0        27.0           7.0       False       False
# 11191   4.0   2.0  81.0         9.0           1.0       False        True
# 1594   12.5  12.5  51.0        16.0           1.0       False       False
# 11102  15.0  15.0  45.0         6.5           2.0       False       False
# 2398    9.5   7.5  79.0        15.0           1.0       False       False
# 2231    6.0   6.0  84.0         2.0           1.0       False       False
# 3519   12.0  12.0  72.0        11.0           3.0       False        True
# 10562   8.5   7.0  79.0         9.0           3.0       False       False
# 1985   10.0   8.0  62.0        15.0           1.0       False       False
# 1774    7.0   5.0  81.0        11.0           4.0       False       False
# 11358   7.0   6.0  66.0         7.0           7.0       False        True
# 2528   11.0  11.0  62.0         7.5           3.0       False        True
# 2362   15.5  15.5  57.0        30.0           2.0       False        True
# 12104  10.0   8.0  67.0        15.0           4.0       False       False
# 10767  10.5   9.0  60.0        24.0           2.0       False       False
# 3357   12.5  12.5  65.0         8.0           4.0       False        True
# 1650    6.0   3.0  78.5        17.0           1.0       False       False
# 11412   6.0   2.0  63.5        24.0           2.0       False       False
# 10140   8.5   6.0  64.0        15.0           2.0       False       False
# 2073   11.0   8.5  54.5        42.5           7.0       False       False
# 2470    9.0   6.0  73.5        18.5           1.0       False       False
# 3251   11.5  11.5  58.0        20.5           2.0       False       False
# 12239  16.0  16.0  61.0        24.0           1.0        True       False
# 2792   14.0  14.0  42.5        22.5           1.0       False       False
# 12124  11.0  11.0  82.0         5.0           4.0       False       False
# 10511   7.0   4.0  73.5        15.0           3.0       False        True
#
#        season  hour  is_daytime
# 11125     0.0    10        True
# 10531     0.0     0       False
# 2874      0.0     2       False
# 1756      0.0     6       False
# 12029     0.0     2       False
# 10403     0.0    16        True
# 10657     0.0     6       False
# 11901     0.0    18        True
# 1903      0.0     9        True
# 2734      0.0     6       False
# 1803      0.0     5       False
# 2506      0.0    18        True
# 11665     0.0    22       False
# 11199     0.0    12        True
# 10867     0.0    15        True
# 11888     0.0     5       False
# 11855     0.0    20       False
# 11666     0.0    23       False
# 11273     0.0    14        True
# 1886      0.0    16        True
# 2655      0.0    23       False
# 12149     0.0     2       False
# 11155     0.0    16        True
# 10163     0.0    16        True
# 12252     0.0     9        True
# 11191     0.0     4       False
# 1594      0.0    12        True
# 11102     0.0    11        True
# 2398      0.0     6       False
# 2231      0.0     7        True
# 3519      0.0    23       False
# 10562     0.0     7        True
# 1985      0.0    19       False
# 1774      0.0     0       False
# 11358     0.0     3       False
# 2528      0.0    16        True
# 2362      0.0    18        True
# 12104     0.0     5       False
# 10767     0.0    11        True
# 3357      0.0     5       False
# 1650      0.0    20       False
# 11412     0.0     9        True
# 10140     0.0    17        True
# 2073      0.0    16        True
# 2470      0.0     6       False
# 3251      0.0    19       False
# 12239     0.0    20       False
# 2792      0.0    16        True
# 12124     0.0     1       False
# 10511     0.0     4       False

# %%
n_comp = 4 #len(mini_trip_df.columns)
# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(mini_trip_df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 0.9877
# Individual variance contributions:
# 0.6610589265111106
# 0.16255819983049513
# 0.10819403319547596
# 0.0558729127869465

# %%
plt.plot(np.arange(pca.n_components_) + 1, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.show()

# %%
pd.DataFrame(pca.components_.T, columns=[f'PC{x}' for x in range(1, n_comp+1)], index=mini_trip_df.columns)
# Out:
#                    PC1       PC2       PC3       PC4
# t1            0.112679 -0.023103  0.285254  0.498227
# t2            0.130788 -0.078139  0.415822  0.679339
# hum          -0.915678  0.263376  0.300134  0.030665
# wind_speed    0.226881  0.949392 -0.158058  0.133340
# weather_code -0.029395  0.047148 -0.056553  0.070435
# is_holiday   -0.000922  0.005250  0.001509  0.015720
# is_weekend    0.003358 -0.012613 -0.007229  0.005146
# season       -0.000000  0.000000  0.000000 -0.000000
# hour          0.281133  0.142256  0.792050 -0.516056
# is_daytime    0.018565  0.001677 -0.007979 -0.000782

# %% [markdown]
# We can leave PC0-PC4 with no loss in data quality!

# %% [markdown]
# ### Bonus question

# %%
plt.scatter(mini_trip_df['hum'], mini_trip_df['hour'])
plt.show()

#how many clusters are there?
#2

# %% [markdown]
# ## Comparing result to larger dataset

# %%
n_comp = 4 #len(trip_df.columns)
# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(trip_df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 0.9840
# Individual variance contributions:
# 0.5939483419542883
# 0.1502806774560688
# 0.13321419706208334
# 0.1065384554853809

# %%
pd.DataFrame(pca.components_.T, columns=[f'PC{x}' for x in range(n_comp)], index=trip_df.columns)
# Out:
#                    PC0       PC1       PC2       PC3
# t1            0.212463 -0.434095 -0.410627 -0.029095
# t2            0.233231 -0.558640 -0.479165 -0.026509
# hum          -0.912818 -0.083942 -0.368775  0.131928
# wind_speed    0.191998  0.694497 -0.671745 -0.150515
# weather_code -0.045756  0.037067 -0.092468  0.015001
# is_holiday   -0.000334  0.000486  0.000182  0.000262
# is_weekend   -0.000712  0.000595 -0.001544  0.000595
# season       -0.021792  0.028045 -0.001052  0.017339
# hour          0.166297  0.089021 -0.077346  0.978706
# is_daytime    0.011836  0.004998 -0.003722 -0.000130

# %% [markdown]
# ## Creating final dataset

# %%
KEEP_PC = 4
new_pca_dataset = pd.DataFrame(X_pca[:, :KEEP_PC], columns=[f'PC{x}' for x in range(KEEP_PC)])
new_pca_dataset
# Out:
#              PC0        PC1        PC2        PC3
# 0     -26.974602  -0.165780   8.348559  -6.489763
# 1     -26.792176  -1.124711   8.888310  -5.403799
# 2     -30.886962  -4.584926  11.084291  -3.196223
# 3     -34.138373  -4.293335  10.161128  -1.727966
# 4     -26.800829   2.014791   9.257192  -2.598086
# ...          ...        ...        ...        ...
# 17409 -10.172774  11.251240   2.231045   8.533539
# 17410  -9.668237  12.766323   0.717740   9.226216
# 17411  -6.421056  14.652323  -0.897800   9.395755
# 17412  -4.164713  14.256702   0.618536  10.195155
# 17413  -4.321749  14.073458   1.842766  11.322175
#
# [17414 rows x 4 columns]
