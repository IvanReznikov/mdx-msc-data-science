# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
np.random.seed(123)

# %% [markdown]
# ## Starter

# %%
data = np.array([[x, x+3] for x in range(-5,5)])

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %%
#Setup
df=pd.DataFrame(data)
n_comp = len(df.columns) #2

# PCA
print('\nRunning PCA ...')
pca = PCA(
    n_components=n_comp, 
    svd_solver='full', 
    random_state=1001
)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 1.0
# 5.154488869341835e-33

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.axis((-10,10,-1, 1))
plt.show()

# %% [markdown]
# ## Simple 2D example

# %%
data = np.array([[0,1], [2,3], [6,0], [8,2], [10,3],
        [20,6], [22,8], [26, 10], [30, 9]])

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %% [markdown]
# #### Locating center

# %%
np.mean(data[:, 0]), np.mean(data[:, 1])
# Out:
# (13.777777777777779, 4.666666666666667)

# %% [markdown]
# ### PCA

# %%
#Setup

df=pd.DataFrame(data)
n_comp = len(df.columns)

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 0.9878291044072529
# 0.012170895592746978

# %%
pca.explained_variance_
# Out:
# array([131.32639149,   1.61805295])

# %%
plt.figure(figsize=(9,3))
plt.scatter(X_pca[:, 0], -X_pca[:, 1])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# ## An even simpler 2D example

# %%
data = np.array([[0,1], [2,3], [6,0], [8,2], [10,3],
        [20,6], [22,8], [26, 10], [30, 9]])

# %%
data[:5, 1] = data[4:, 1][::-1]

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %%
#Setup

df=pd.DataFrame(data)
n_comp = len(df.columns)

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 0.9583962060966892
# 0.04160379390331084

# %%
plt.figure(figsize=(9,3))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# ## A bit more complex 2D example

# %%
data = np.array([[0,1], [2,3], [6,0], [8,2], [10,3],
        [20,6], [22,8], [26, 10], [30, 9]])

# %%
data[:5, 0] = data[4:, 0][::-1]

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %%
#Setup

df=pd.DataFrame(data)
n_comp = len(df.columns)

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 0.7598588649121777
# 0.24014113508782228

# %%
plt.figure(figsize=(9,3))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# ## Simple ND examples

# %%
df.head()
# Out:
#     0  1
# 0  30  1
# 1  26  3
# 2  22  0
# 3  20  2
# 4  10  3

# %%
df[2] = 2*df[0] + df[1] - 1
df[3] = df[0]/2 + df[1]**1.5 + 3
df[4] = np.sqrt(df[0]) + np.log2(df[1]+0.5)
df[5] = df[0] - df[1]

# %%
df.head()
# Out:
#     0  1   2          3         4   5
# 0  30  1  60  19.000000  6.062188  29
# 1  26  3  54  21.196152  6.906374  23
# 2  22  0  43  14.000000  3.690416  22
# 3  20  2  41  15.828427  5.794064  18
# 4  10  3  22  13.196152  4.969633   7

# %%
n_comp = len(df.columns)

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 0.7659170493626792
# 0.2320792160695266
# 0.001971279907865211
# 3.2454659928926255e-05
# 5.6139665418565946e-33
# 1.2408626426311611e-33

# %% [markdown]
# ## Slightly more complex ND example

# %%
df.head()
# Out:
#     0  1   2          3         4   5
# 0  30  1  60  19.000000  6.062188  29
# 1  26  3  54  21.196152  6.906374  23
# 2  22  0  43  14.000000  3.690416  22
# 3  20  2  41  15.828427  5.794064  18
# 4  10  3  22  13.196152  4.969633   7

# %%
df[5] += np.random.randint(df.min().min(),df.max().max(), size=df.shape[0])

# %%
df.head()
# Out:
#     0  1   2          3         4   5
# 0  30  1  60  19.000000  6.062188  95
# 1  26  3  54  21.196152  6.906374  40
# 2  22  0  43  14.000000  3.690416  79
# 3  20  2  41  15.828427  5.794064  65
# 4  10  3  22  13.196152  4.969633  39

# %%
n_comp = len(df.columns)

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 1.0000
# Individual variance contributions:
# 0.5509865866221856
# 0.4062578603668873
# 0.04211952287969814
# 0.000623066707366231
# 1.2963423862710973e-05
# 2.328298096367871e-33

# %%
plt.plot(np.arange(pca.n_components_) + 1, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.show()

# %%
df.corr()

#col0 -- col2; 
#col1 -- col3 -- col4; 
#col5
# Out:
#           0         1         2         3         4         5
# 0  1.000000  0.235129  0.965350  0.498449  0.505359  0.508478
# 1  0.235129  1.000000  0.480625  0.952485  0.901246 -0.402612
# 2  0.965350  0.480625  1.000000  0.705441  0.697919  0.350664
# 3  0.498449  0.952485  0.705441  1.000000  0.910060 -0.174667
# 4  0.505359  0.901246  0.697919  0.910060  1.000000 -0.264834
# 5  0.508478 -0.402612  0.350664 -0.174667 -0.264834  1.000000

# %%
pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6'], index=df.columns)

#PC1 has strong loadings from col5
# Out:
#         PC1       PC2       PC3       PC4       PC5           PC6
# 0  0.229839  0.171711  0.390629  0.201887  0.240152 -8.164966e-01
# 1 -0.019697  0.186844 -0.232174 -0.516370 -0.691008 -4.082483e-01
# 2  0.439981  0.530267  0.549084 -0.112597 -0.210703  4.082483e-01
# 3  0.098668  0.701830 -0.625068  0.251709  0.208882 -1.387779e-17
# 4  0.005995  0.086055 -0.013244 -0.784586  0.613847 -1.376503e-15
# 5  0.862225 -0.393003 -0.318001 -0.031505 -0.000454  2.775558e-17

# %%
plt.figure(figsize=(9,3))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# ### Limit components

# %%
n_comp = 2

# PCA
print('\nRunning PCA ...')
pca = PCA(n_components=n_comp, svd_solver='full', random_state=1001)
X_pca = pca.fit_transform(df)
print('Explained variance: %.4f' % pca.explained_variance_ratio_.sum())

print('Individual variance contributions:')
for j in range(n_comp):
    print(pca.explained_variance_ratio_[j])
# Out:
# Running PCA ...
# Explained variance: 0.9572
# Individual variance contributions:
# 0.5509865866221856
# 0.4062578603668873
